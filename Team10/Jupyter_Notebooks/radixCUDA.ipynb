#                                                   154514164                comm
#                                                   329078241                comm
#                                                   333888426                comm
#                                                   379554899                comm
#                                                   387338399                comm
#                                                   414498271                comm
#                                                   627822010                comm
#                                                   675422748                comm
#                                                   759761496                comm
#                                                   886088404                comm
#                                                   1215402717               comm
#                                                   1221154219               comm
#                                                   1487286289               comm
#                                                   1707158041               comm
#                                                   1750563714               comm
#                                                   1854694556               comm
#                                                   2103287927               comm
#                                                   2117249302               comm
#                                                   2307086009               comm
#                                                   2470599784               comm
#                                                   2566690557               comm
#                                                   2596015767               comm
#                                                   2599862744               comm
#                                                   3011088583               comm
#                                                   3144157472               comm
#                                                   3186243202               comm
#                                                   3189081541               comm
#                                                   3362082510               comm
#                                                   3551453612               comm
#                                                   3578694289               comm
#                                                   3613854097               comm
#                                                   3869713418               comm
#                                                   3957604448               comm
#                                                   3963073995               comm
# {'name': 'comm_large', 'type': 'function'}        130835220          comm_large
#                                                   154514164          comm_large
#                                                   329078241          comm_large
#                                                   333888426          comm_large
#                                                   379554899          comm_large
#                                                   387338399          comm_large
#                                                   414498271          comm_large
#                                                   627822010          comm_large
#                                                   675422748          comm_large
#                                                   759761496          comm_large
#                                                   886088404          comm_large
#                                                   1215402717         comm_large
#                                                   1221154219         comm_large
#                                                   1487286289         comm_large
#                                                   1707158041         comm_large
#                                                   1750563714         comm_large
#                                                   1854694556         comm_large
#                                                   2103287927         comm_large
#                                                   2117249302         comm_large
#                                                   2307086009         comm_large
#                                                   2470599784         comm_large
#                                                   2566690557         comm_large
#                                                   2596015767         comm_large
#                                                   2599862744         comm_large
#                                                   3011088583         comm_large
#                                                   3144157472         comm_large
#                                                   3186243202         comm_large
#                                                   3189081541         comm_large
#                                                   3362082510         comm_large
#                                                   3551453612         comm_large
#                                                   3578694289         comm_large
#                                                   3613854097         comm_large
#                                                   3869713418         comm_large
#                                                   3957604448         comm_large
#                                                   3963073995         comm_large
# {'name': 'cudaMemcpy', 'type': 'function'}        130835220          cudaMemcpy
#                                                   154514164          cudaMemcpy
#                                                   329078241          cudaMemcpy
#                                                   333888426          cudaMemcpy
#                                                   379554899          cudaMemcpy
#                                                   387338399          cudaMemcpy
#                                                   414498271          cudaMemcpy
#                                                   627822010          cudaMemcpy
#                                                   675422748          cudaMemcpy
#                                                   759761496          cudaMemcpy
#                                                   886088404          cudaMemcpy
#                                                   1215402717         cudaMemcpy
#                                                   1221154219         cudaMemcpy
#                                                   1487286289         cudaMemcpy
#                                                   1707158041         cudaMemcpy
#                                                   1750563714         cudaMemcpy
#                                                   1854694556         cudaMemcpy
#                                                   2103287927         cudaMemcpy
#                                                   2117249302         cudaMemcpy
#                                                   2307086009         cudaMemcpy
#                                                   2470599784         cudaMemcpy
#                                                   2566690557         cudaMemcpy
#                                                   2596015767         cudaMemcpy
#                                                   2599862744         cudaMemcpy
#                                                   3011088583         cudaMemcpy
#                                                   3144157472         cudaMemcpy
#                                                   3186243202         cudaMemcpy
#                                                   3189081541         cudaMemcpy
#                                                   3362082510         cudaMemcpy
#                                                   3551453612         cudaMemcpy
#                                                   3578694289         cudaMemcpy
#                                                   3613854097         cudaMemcpy
#                                                   3869713418         cudaMemcpy
#                                                   3957604448         cudaMemcpy
#                                                   3963073995         cudaMemcpy
# {'name': 'comp', 'type': 'function'}              130835220                comp
#                                                   154514164                comp
#                                                   329078241                comp
#                                                   333888426                comp
#                                                   379554899                comp
#                                                   387338399                comp
#                                                   414498271                comp
#                                                   627822010                comp
#                                                   675422748                comp
#                                                   759761496                comp
#                                                   886088404                comp
#                                                   1215402717               comp
#                                                   1221154219               comp
#                                                   1487286289               comp
#                                                   1707158041               comp
#                                                   1750563714               comp
#                                                   1854694556               comp
#                                                   2103287927               comp
#                                                   2117249302               comp
#                                                   2307086009               comp
#                                                   2470599784               comp
#                                                   2566690557               comp
#                                                   2596015767               comp
#                                                   2599862744               comp
#                                                   3011088583               comp
#                                                   3144157472               comp
#                                                   3186243202               comp
#                                                   3189081541               comp
#                                                   3362082510               comp
#                                                   3551453612               comp
#                                                   3578694289               comp
#                                                   3613854097               comp
#                                                   3869713418               comp
#                                                   3957604448               comp
#                                                   3963073995               comp
# {'name': 'comp_large', 'type': 'function'}        130835220          comp_large
#                                                   154514164          comp_large
#                                                   329078241          comp_large
#                                                   333888426          comp_large
#                                                   379554899          comp_large
#                                                   387338399          comp_large
#                                                   414498271          comp_large
#                                                   627822010          comp_large
#                                                   675422748          comp_large
#                                                   759761496          comp_large
#                                                   886088404          comp_large
#                                                   1215402717         comp_large
#                                                   1221154219         comp_large
#                                                   1487286289         comp_large
#                                                   1707158041         comp_large
#                                                   1750563714         comp_large
#                                                   1854694556         comp_large
#                                                   2103287927         comp_large
#                                                   2117249302         comp_large
#                                                   2307086009         comp_large
#                                                   2470599784         comp_large
#                                                   2566690557         comp_large
#                                                   2596015767         comp_large
#                                                   2599862744         comp_large
#                                                   3011088583         comp_large
#                                                   3144157472         comp_large
#                                                   3186243202         comp_large
#                                                   3189081541         comp_large
#                                                   3362082510         comp_large
#                                                   3551453612         comp_large
#                                                   3578694289         comp_large
#                                                   3613854097         comp_large
#                                                   3869713418         comp_large
#                                                   3957604448         comp_large
#                                                   3963073995         comp_large
# {'name': 'correctness_check', 'type': 'function'} 130835220   correctness_check
#                                                   154514164   correctness_check
#                                                   329078241   correctness_check
#                                                   333888426   correctness_check
#                                                   379554899   correctness_check
#                                                   387338399   correctness_check
#                                                   414498271   correctness_check
#                                                   627822010   correctness_check
#                                                   675422748   correctness_check
#                                                   759761496   correctness_check
#                                                   886088404   correctness_check
#                                                   1215402717  correctness_check
#                                                   1221154219  correctness_check
#                                                   1487286289  correctness_check
#                                                   1707158041  correctness_check
#                                                   1750563714  correctness_check
#                                                   1854694556  correctness_check
#                                                   2103287927  correctness_check
#                                                   2117249302  correctness_check
#                                                   2307086009  correctness_check
#                                                   2470599784  correctness_check
#                                                   2566690557  correctness_check
#                                                   2596015767  correctness_check
#                                                   2599862744  correctness_check
#                                                   3011088583  correctness_check
#                                                   3144157472  correctness_check
#                                                   3186243202  correctness_check
#                                                   3189081541  correctness_check
#                                                   3362082510  correctness_check
#                                                   3551453612  correctness_check
#                                                   3578694289  correctness_check
#                                                   3613854097  correctness_check
#                                                   3869713418  correctness_check
#                                                   3957604448  correctness_check
#                                                   3963073995  correctness_check
# {'name': 'data_init', 'type': 'function'}         130835220           data_init
#                                                   154514164           data_init
#                                                   329078241           data_init
#                                                   333888426           data_init
#                                                   379554899           data_init
#                                                   387338399           data_init
#                                                   414498271           data_init
#                                                   627822010           data_init
#                                                   675422748           data_init
#                                                   759761496           data_init
#                                                   886088404           data_init
#                                                   1215402717          data_init
#                                                   1221154219          data_init
#                                                   1487286289          data_init
#                                                   1707158041          data_init
#                                                   1750563714          data_init
#                                                   1854694556          data_init
#                                                   2103287927          data_init
#                                                   2117249302          data_init
#                                                   2307086009          data_init
#                                                   2470599784          data_init
#                                                   2566690557          data_init
#                                                   2596015767          data_init
#                                                   2599862744          data_init
#                                                   3011088583          data_init
#                                                   3144157472          data_init
#                                                   3186243202          data_init
#                                                   3189081541          data_init
#                                                   3362082510          data_init
#                                                   3551453612          data_init
#                                                   3578694289          data_init
#                                                   3613854097          data_init
#                                                   3869713418          data_init
#                                                   3957604448          data_init
#                                                   3963073995          data_init

# %%
tk.metadata
#available_metrics = tk.statsframe.show_metric_columns()
#print("Available metric columns:", available_metrics)
# Out:
#            cali.caliper.version  \
# profile
# 130835220            2.11.0-dev
# 154514164            2.11.0-dev
# 329078241            2.11.0-dev
# 333888426            2.11.0-dev
# 379554899            2.11.0-dev
# 387338399            2.11.0-dev
# 414498271            2.11.0-dev
# 627822010            2.11.0-dev
# 675422748            2.11.0-dev
# 759761496            2.11.0-dev
# 886088404            2.11.0-dev
# 1215402717           2.11.0-dev
# 1221154219           2.11.0-dev
# 1487286289           2.11.0-dev
# 1707158041           2.11.0-dev
# 1750563714           2.11.0-dev
# 1854694556           2.11.0-dev
# 2103287927           2.11.0-dev
# 2117249302           2.11.0-dev
# 2307086009           2.11.0-dev
# 2470599784           2.11.0-dev
# 2566690557           2.11.0-dev
# 2596015767           2.11.0-dev
# 2599862744           2.11.0-dev
# 3011088583           2.11.0-dev
# 3144157472           2.11.0-dev
# 3186243202           2.11.0-dev
# 3189081541           2.11.0-dev
# 3362082510           2.11.0-dev
# 3551453612           2.11.0-dev
# 3578694289           2.11.0-dev
# 3613854097           2.11.0-dev
# 3869713418           2.11.0-dev
# 3957604448           2.11.0-dev
# 3963073995           2.11.0-dev
#
#                                                  spot.metrics  \
# profile
# 130835220   min#inclusive#sum#time.duration,max#inclusive#...
# 154514164   min#inclusive#sum#time.duration,max#inclusive#...
# 329078241   min#inclusive#sum#time.duration,max#inclusive#...
# 333888426   min#inclusive#sum#time.duration,max#inclusive#...
# 379554899   min#inclusive#sum#time.duration,max#inclusive#...
# 387338399   min#inclusive#sum#time.duration,max#inclusive#...
# 414498271   min#inclusive#sum#time.duration,max#inclusive#...
# 627822010   min#inclusive#sum#time.duration,max#inclusive#...
# 675422748   min#inclusive#sum#time.duration,max#inclusive#...
# 759761496   min#inclusive#sum#time.duration,max#inclusive#...
# 886088404   min#inclusive#sum#time.duration,max#inclusive#...
# 1215402717  min#inclusive#sum#time.duration,max#inclusive#...
# 1221154219  min#inclusive#sum#time.duration,max#inclusive#...
# 1487286289  min#inclusive#sum#time.duration,max#inclusive#...
# 1707158041  min#inclusive#sum#time.duration,max#inclusive#...
# 1750563714  min#inclusive#sum#time.duration,max#inclusive#...
# 1854694556  min#inclusive#sum#time.duration,max#inclusive#...
# 2103287927  min#inclusive#sum#time.duration,max#inclusive#...
# 2117249302  min#inclusive#sum#time.duration,max#inclusive#...
# 2307086009  min#inclusive#sum#time.duration,max#inclusive#...
# 2470599784  min#inclusive#sum#time.duration,max#inclusive#...
# 2566690557  min#inclusive#sum#time.duration,max#inclusive#...
# 2596015767  min#inclusive#sum#time.duration,max#inclusive#...
# 2599862744  min#inclusive#sum#time.duration,max#inclusive#...
# 3011088583  min#inclusive#sum#time.duration,max#inclusive#...
# 3144157472  min#inclusive#sum#time.duration,max#inclusive#...
# 3186243202  min#inclusive#sum#time.duration,max#inclusive#...
# 3189081541  min#inclusive#sum#time.duration,max#inclusive#...
# 3362082510  min#inclusive#sum#time.duration,max#inclusive#...
# 3551453612  min#inclusive#sum#time.duration,max#inclusive#...
# 3578694289  min#inclusive#sum#time.duration,max#inclusive#...
# 3613854097  min#inclusive#sum#time.duration,max#inclusive#...
# 3869713418  min#inclusive#sum#time.duration,max#inclusive#...
# 3957604448  min#inclusive#sum#time.duration,max#inclusive#...
# 3963073995  min#inclusive#sum#time.duration,max#inclusive#...
#
#            spot.timeseries.metrics  spot.format.version  \
# profile
# 130835220                                             2
# 154514164                                             2
# 329078241                                             2
# 333888426                                             2
# 379554899                                             2
# 387338399                                             2
# 414498271                                             2
# 627822010                                             2
# 675422748                                             2
# 759761496                                             2
# 886088404                                             2
# 1215402717                                            2
# 1221154219                                            2
# 1487286289                                            2
# 1707158041                                            2
# 1750563714                                            2
# 1854694556                                            2
# 2103287927                                            2
# 2117249302                                            2
# 2307086009                                            2
# 2470599784                                            2
# 2566690557                                            2
# 2596015767                                            2
# 2599862744                                            2
# 3011088583                                            2
# 3144157472                                            2
# 3186243202                                            2
# 3189081541                                            2
# 3362082510                                            2
# 3551453612                                            2
# 3578694289                                            2
# 3613854097                                            2
# 3869713418                                            2
# 3957604448                                            2
# 3963073995                                            2
#
#                        spot.options  spot.channels cali.channel  \
# profile
# 130835220   cuda.gputime,node.order  regionprofile         spot
# 154514164   cuda.gputime,node.order  regionprofile         spot
# 329078241   cuda.gputime,node.order  regionprofile         spot
# 333888426   cuda.gputime,node.order  regionprofile         spot
# 379554899   cuda.gputime,node.order  regionprofile         spot
# 387338399   cuda.gputime,node.order  regionprofile         spot
# 414498271   cuda.gputime,node.order  regionprofile         spot
# 627822010   cuda.gputime,node.order  regionprofile         spot
# 675422748   cuda.gputime,node.order  regionprofile         spot
# 759761496   cuda.gputime,node.order  regionprofile         spot
# 886088404   cuda.gputime,node.order  regionprofile         spot
# 1215402717  cuda.gputime,node.order  regionprofile         spot
# 1221154219  cuda.gputime,node.order  regionprofile         spot
# 1487286289  cuda.gputime,node.order  regionprofile         spot
# 1707158041  cuda.gputime,node.order  regionprofile         spot
# 1750563714  cuda.gputime,node.order  regionprofile         spot
# 1854694556  cuda.gputime,node.order  regionprofile         spot
# 2103287927  cuda.gputime,node.order  regionprofile         spot
# 2117249302  cuda.gputime,node.order  regionprofile         spot
# 2307086009  cuda.gputime,node.order  regionprofile         spot
# 2470599784  cuda.gputime,node.order  regionprofile         spot
# 2566690557  cuda.gputime,node.order  regionprofile         spot
# 2596015767  cuda.gputime,node.order  regionprofile         spot
# 2599862744  cuda.gputime,node.order  regionprofile         spot
# 3011088583  cuda.gputime,node.order  regionprofile         spot
# 3144157472  cuda.gputime,node.order  regionprofile         spot
# 3186243202  cuda.gputime,node.order  regionprofile         spot
# 3189081541  cuda.gputime,node.order  regionprofile         spot
# 3362082510  cuda.gputime,node.order  regionprofile         spot
# 3551453612  cuda.gputime,node.order  regionprofile         spot
# 3578694289  cuda.gputime,node.order  regionprofile         spot
# 3613854097  cuda.gputime,node.order  regionprofile         spot
# 3869713418  cuda.gputime,node.order  regionprofile         spot
# 3957604448  cuda.gputime,node.order  regionprofile         spot
# 3963073995  cuda.gputime,node.order  regionprofile         spot
#
#            spot:cuda.gputime spot:node.order               spot:output  \
# profile
# 130835220               true            true   t256-v268435456-i4.cali
# 154514164               true            true   t1024-v16777216-i4.cali
# 329078241               true            true   t1024-v67108864-i4.cali
# 333888426               true            true      t64-v4194304-i4.cali
# 379554899               true            true     t512-v4194304-i4.cali
# 387338399               true            true  t1024-v268435456-i4.cali
# 414498271               true            true        t64-v65536-i4.cali
# 627822010               true            true      t256-v262144-i4.cali
# 675422748               true            true      t128-v262144-i4.cali
# 759761496               true            true     t64-v16777216-i4.cali
# 886088404               true            true    t1024-v4194304-i4.cali
# 1215402717              true            true    t512-v67108864-i4.cali
# 1221154219              true            true    t1024-v1048576-i4.cali
# 1487286289              true            true    t256-v16777216-i4.cali
# 1707158041              true            true    t256-v67108864-i4.cali
# 1750563714              true            true       t256-v65536-i4.cali
# 1854694556              true            true     t64-v67108864-i4.cali
# 2103287927              true            true     t256-v4194304-i4.cali
# 2117249302              true            true    t64-v268435456-i4.cali
# 2307086009              true            true       t512-v65536-i4.cali
# 2470599784              true            true      t512-v262144-i4.cali
# 2566690557              true            true     t128-v1048576-i4.cali
# 2596015767              true            true    t128-v16777216-i4.cali
# 2599862744              true            true   t512-v268435456-i4.cali
# 3011088583              true            true    t128-v67108864-i4.cali
# 3144157472              true            true      t64-v1048576-i4.cali
# 3186243202              true            true     t256-v1048576-i4.cali
# 3189081541              true            true     t1024-v262144-i4.cali
# 3362082510              true            true      t1024-v65536-i4.cali
# 3551453612              true            true   t128-v268435456-i4.cali
# 3578694289              true            true     t512-v1048576-i4.cali
# 3613854097              true            true       t64-v262144-i4.cali
# 3869713418              true            true       t128-v65536-i4.cali
# 3957604448              true            true     t128-v4194304-i4.cali
# 3963073995              true            true    t512-v16777216-i4.cali
#
#             launchdate                                          libraries  \
# profile
# 130835220   1701217392  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 154514164   1701218680  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 329078241   1701215869  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 333888426   1701215509  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 379554899   1701215589  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 387338399   1701218660  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 414498271   1701214640  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 627822010   1701215062  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 675422748   1701215024  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 759761496   1701218598  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 886088404   1701215611  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1215402717  1701215832  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1221154219  1701215351  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1487286289  1701218630  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1707158041  1701215810  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1750563714  1701214822  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1854694556  1701215689  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2103287927  1701215550  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2117249302  1701216370  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2307086009  1701214882  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2470599784  1701215101  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2566690557  1701215245  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2596015767  1701218630  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2599862744  1701218552  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3011088583  1701215750  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3144157472  1701215205  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3186243202  1701215287  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3189081541  1701215144  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3362082510  1701214942  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3551453612  1701217149  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3578694289  1701215322  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3613854097  1701214983  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3869713418  1701214763  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3957604448  1701215539  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3963073995  1701218638  [/scratch/group/csce435-f23/Caliper/caliper/li...
#
#                                   cmdline cluster  Algorithm ProgrammingModel  \
# profile
# 130835220    [./radix, 256, 268435456, 4]       g  RadixSort             CUDA
# 154514164    [./radix, 1024, 16777216, 4]       g  RadixSort             CUDA
# 329078241    [./radix, 1024, 67108864, 4]       g  RadixSort             CUDA
# 333888426       [./radix, 64, 4194304, 4]       g  RadixSort             CUDA
# 379554899      [./radix, 512, 4194304, 4]       g  RadixSort             CUDA
# 387338399   [./radix, 1024, 268435456, 4]       g  RadixSort             CUDA
# 414498271         [./radix, 64, 65536, 4]       g  RadixSort             CUDA
# 627822010       [./radix, 256, 262144, 4]       g  RadixSort             CUDA
# 675422748       [./radix, 128, 262144, 4]       g  RadixSort             CUDA
# 759761496      [./radix, 64, 16777216, 4]       g  RadixSort             CUDA
# 886088404     [./radix, 1024, 4194304, 4]       g  RadixSort             CUDA
# 1215402717    [./radix, 512, 67108864, 4]       g  RadixSort             CUDA
# 1221154219    [./radix, 1024, 1048576, 4]       g  RadixSort             CUDA
# 1487286289    [./radix, 256, 16777216, 4]       g  RadixSort             CUDA
# 1707158041    [./radix, 256, 67108864, 4]       g  RadixSort             CUDA
# 1750563714       [./radix, 256, 65536, 4]       g  RadixSort             CUDA
# 1854694556     [./radix, 64, 67108864, 4]       g  RadixSort             CUDA
# 2103287927     [./radix, 256, 4194304, 4]       g  RadixSort             CUDA
# 2117249302    [./radix, 64, 268435456, 4]       g  RadixSort             CUDA
# 2307086009       [./radix, 512, 65536, 4]       g  RadixSort             CUDA
# 2470599784      [./radix, 512, 262144, 4]       g  RadixSort             CUDA
# 2566690557     [./radix, 128, 1048576, 4]       g  RadixSort             CUDA
# 2596015767    [./radix, 128, 16777216, 4]       g  RadixSort             CUDA
# 2599862744   [./radix, 512, 268435456, 4]       g  RadixSort             CUDA
# 3011088583    [./radix, 128, 67108864, 4]       g  RadixSort             CUDA
# 3144157472      [./radix, 64, 1048576, 4]       g  RadixSort             CUDA
# 3186243202     [./radix, 256, 1048576, 4]       g  RadixSort             CUDA
# 3189081541     [./radix, 1024, 262144, 4]       g  RadixSort             CUDA
# 3362082510      [./radix, 1024, 65536, 4]       g  RadixSort             CUDA
# 3551453612   [./radix, 128, 268435456, 4]       g  RadixSort             CUDA
# 3578694289     [./radix, 512, 1048576, 4]       g  RadixSort             CUDA
# 3613854097       [./radix, 64, 262144, 4]       g  RadixSort             CUDA
# 3869713418       [./radix, 128, 65536, 4]       g  RadixSort             CUDA
# 3957604448     [./radix, 128, 4194304, 4]       g  RadixSort             CUDA
# 3963073995    [./radix, 512, 16777216, 4]       g  RadixSort             CUDA
#
#            Datatype  SizeOfDatatype  InputSize    InputType  num_threads  \
# profile
# 130835220       int               4  268435456  1%perturbed          256
# 154514164       int               4   16777216  1%perturbed         1024
# 329078241       int               4   67108864  1%perturbed         1024
# 333888426       int               4    4194304  1%perturbed           64
# 379554899       int               4    4194304  1%perturbed          512
# 387338399       int               4  268435456  1%perturbed         1024
# 414498271       int               4      65536  1%perturbed           64
# 627822010       int               4     262144  1%perturbed          256
# 675422748       int               4     262144  1%perturbed          128
# 759761496       int               4   16777216  1%perturbed           64
# 886088404       int               4    4194304  1%perturbed         1024
# 1215402717      int               4   67108864  1%perturbed          512
# 1221154219      int               4    1048576  1%perturbed         1024
# 1487286289      int               4   16777216  1%perturbed          256
# 1707158041      int               4   67108864  1%perturbed          256
# 1750563714      int               4      65536  1%perturbed          256
# 1854694556      int               4   67108864  1%perturbed           64
# 2103287927      int               4    4194304  1%perturbed          256
# 2117249302      int               4  268435456  1%perturbed           64
# 2307086009      int               4      65536  1%perturbed          512
# 2470599784      int               4     262144  1%perturbed          512
# 2566690557      int               4    1048576  1%perturbed          128
# 2596015767      int               4   16777216  1%perturbed          128
# 2599862744      int               4  268435456  1%perturbed          512
# 3011088583      int               4   67108864  1%perturbed          128
# 3144157472      int               4    1048576  1%perturbed           64
# 3186243202      int               4    1048576  1%perturbed          256
# 3189081541      int               4     262144  1%perturbed         1024
# 3362082510      int               4      65536  1%perturbed         1024
# 3551453612      int               4  268435456  1%perturbed          128
# 3578694289      int               4    1048576  1%perturbed          512
# 3613854097      int               4     262144  1%perturbed           64
# 3869713418      int               4      65536  1%perturbed          128
# 3957604448      int               4    4194304  1%perturbed          128
# 3963073995      int               4   16777216  1%perturbed          512
#
#             num_blocks  group_num implementation_source  data_init  comm  \
# profile
# 130835220      1048576         10                Online  data_init  comm
# 154514164        16384         10                Online  data_init  comm
# 329078241        65536         10                Online  data_init  comm
# 333888426        65536         10                Online  data_init  comm
# 379554899         8192         10                Online  data_init  comm
# 387338399       262144         10                Online  data_init  comm
# 414498271         1024         10                Online  data_init  comm
# 627822010         1024         10                Online  data_init  comm
# 675422748         2048         10                Online  data_init  comm
# 759761496       262144         10                Online  data_init  comm
# 886088404         4096         10                Online  data_init  comm
# 1215402717      131072         10                Online  data_init  comm
# 1221154219        1024         10                Online  data_init  comm
# 1487286289       65536         10                Online  data_init  comm
# 1707158041      262144         10                Online  data_init  comm
# 1750563714         256         10                Online  data_init  comm
# 1854694556     1048576         10                Online  data_init  comm
# 2103287927       16384         10                Online  data_init  comm
# 2117249302     4194304         10                Online  data_init  comm
# 2307086009         128         10                Online  data_init  comm
# 2470599784         512         10                Online  data_init  comm
# 2566690557        8192         10                Online  data_init  comm
# 2596015767      131072         10                Online  data_init  comm
# 2599862744      524288         10                Online  data_init  comm
# 3011088583      524288         10                Online  data_init  comm
# 3144157472       16384         10                Online  data_init  comm
# 3186243202        4096         10                Online  data_init  comm
# 3189081541         256         10                Online  data_init  comm
# 3362082510          64         10                Online  data_init  comm
# 3551453612     2097152         10                Online  data_init  comm
# 3578694289        2048         10                Online  data_init  comm
# 3613854097        4096         10                Online  data_init  comm
# 3869713418         512         10                Online  data_init  comm
# 3957604448       32768         10                Online  data_init  comm
# 3963073995       32768         10                Online  data_init  comm
#
#             comp  comm_large  comp_large  correctness_check  cudaMemcpy
# profile
# 130835220   comp  comm_large  comp_large  correctness_check  cudaMemcpy
# 154514164   comp  comm_large  comp_large  correctness_check  cudaMemcpy
# 329078241   comp  comm_large  comp_large  correctness_check  cudaMemcpy
# 333888426   comp  comm_large  comp_large  correctness_check  cudaMemcpy
# 379554899   comp  comm_large  comp_large  correctness_check  cudaMemcpy
# 387338399   comp  comm_large  comp_large  correctness_check  cudaMemcpy
# 414498271   comp  comm_large  comp_large  correctness_check  cudaMemcpy
# 627822010   comp  comm_large  comp_large  correctness_check  cudaMemcpy
# 675422748   comp  comm_large  comp_large  correctness_check  cudaMemcpy
# 759761496   comp  comm_large  comp_large  correctness_check  cudaMemcpy
# 886088404   comp  comm_large  comp_large  correctness_check  cudaMemcpy
# 1215402717  comp  comm_large  comp_large  correctness_check  cudaMemcpy
# 1221154219  comp  comm_large  comp_large  correctness_check  cudaMemcpy
# 1487286289  comp  comm_large  comp_large  correctness_check  cudaMemcpy
# 1707158041  comp  comm_large  comp_large  correctness_check  cudaMemcpy
# 1750563714  comp  comm_large  comp_large  correctness_check  cudaMemcpy
# 1854694556  comp  comm_large  comp_large  correctness_check  cudaMemcpy
# 2103287927  comp  comm_large  comp_large  correctness_check  cudaMemcpy
# 2117249302  comp  comm_large  comp_large  correctness_check  cudaMemcpy
# 2307086009  comp  comm_large  comp_large  correctness_check  cudaMemcpy
# 2470599784  comp  comm_large  comp_large  correctness_check  cudaMemcpy
# 2566690557  comp  comm_large  comp_large  correctness_check  cudaMemcpy
# 2596015767  comp  comm_large  comp_large  correctness_check  cudaMemcpy
# 2599862744  comp  comm_large  comp_large  correctness_check  cudaMemcpy
# 3011088583  comp  comm_large  comp_large  correctness_check  cudaMemcpy
# 3144157472  comp  comm_large  comp_large  correctness_check  cudaMemcpy
# 3186243202  comp  comm_large  comp_large  correctness_check  cudaMemcpy
# 3189081541  comp  comm_large  comp_large  correctness_check  cudaMemcpy
# 3362082510  comp  comm_large  comp_large  correctness_check  cudaMemcpy
# 3551453612  comp  comm_large  comp_large  correctness_check  cudaMemcpy
# 3578694289  comp  comm_large  comp_large  correctness_check  cudaMemcpy
# 3613854097  comp  comm_large  comp_large  correctness_check  cudaMemcpy
# 3869713418  comp  comm_large  comp_large  correctness_check  cudaMemcpy
# 3957604448  comp  comm_large  comp_large  correctness_check  cudaMemcpy
# 3963073995  comp  comm_large  comp_large  correctness_check  cudaMemcpy

# %%
tk.statsframe.dataframe["time"] = 1
print(tk.tree())
# Out:
#   _____ _     _      _        _
#  |_   _| |__ (_) ___| | _____| |_
#    | | | '_ \| |/ __| |/ / _ \ __|
#    | | | | | | | (__|   <  __/ |_
#    |_| |_| |_|_|\___|_|\_\___|\__|  v2023.3.0
#
# 1.000 main
# ├─ 1.000 comm
# │  └─ 1.000 comm_large
# │     └─ 1.000 cudaMemcpy
# ├─ 1.000 comp
# │  └─ 1.000 comp_large
# ├─ 1.000 correctness_check
# └─ 1.000 data_init
#
# Legend (Metric: time Min: 1.00 Max: 1.00)
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
#
# name User code    ◀  Only in left graph    ▶  Only in right graph

# %%
tk.metadata.columns
# Out:
# Index(['cali.caliper.version', 'spot.metrics', 'spot.timeseries.metrics',
#        'spot.format.version', 'spot.options', 'spot.channels', 'cali.channel',
#        'spot:cuda.gputime', 'spot:node.order', 'spot:output', 'launchdate',
#        'libraries', 'cmdline', 'cluster', 'Algorithm', 'ProgrammingModel',
#        'Datatype', 'SizeOfDatatype', 'InputSize', 'InputType', 'num_threads',
#        'num_blocks', 'group_num', 'implementation_source', 'data_init', 'comm',
#        'comp', 'comm_large', 'comp_large', 'correctness_check', 'cudaMemcpy'],
#       dtype='object')

# %%
gb = tk.groupby("InputType")
#gb = tk.groupby("InputSize")
# Out:
# 1  thickets created...
# {'1%perturbed': <thicket.thicket.Thicket object at 0x2ab5248c2eb0>}

# %%
ctk = th.Thicket.concat_thickets(
    thickets=list(gb.values()),
    headers=list(gb.keys()),
    axis="columns",
     metadata_key="num_threads"
)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-7-948179ee04d9> in <module>
# ----> 1 ctk = th.Thicket.concat_thickets(
#       2     thickets=list(gb.values()),
#       3     headers=list(gb.keys()),
#       4     axis="columns",
#       5      metadata_key="num_threads"
#
# /scratch/group/csce435-f23/thicket/thicket/thicket.py in concat_thickets(thickets, axis, calltree, **kwargs)
#     322             ct = _index(thickets, **kwargs)
#     323         elif axis == "columns":
# --> 324             ct = _columns(thickets, **kwargs)
#     325         else:
#     326             raise ValueError("axis must be 'index' or 'columns'")
#
# /scratch/group/csce435-f23/thicket/thicket/thicket.py in _columns(thickets, headers, metadata_key)
#     310
#     311         def _columns(thickets, headers=None, metadata_key=None):
# --> 312             combined_thicket = Ensemble._columns(
#     313                 thickets=thickets, headers=headers, metadata_key=metadata_key
#     314             )
#
# /scratch/group/csce435-f23/thicket/thicket/ensemble.py in _columns(thickets, headers, metadata_key)
#     288
#     289         # Validate dataframe
# --> 290         validate_dataframe(combined_th.dataframe)
#     291
#     292         return combined_th
#
# /scratch/group/csce435-f23/thicket/thicket/utils.py in validate_dataframe(df)
#      44                     )
#      45
# ---> 46     _check_duplicate_inner_idx(df)
#      47     _check_missing_hnid(df)
#      48     _validate_name_column(df)
#
# /scratch/group/csce435-f23/thicket/thicket/utils.py in _check_duplicate_inner_idx(df)
#      18             inner_idx_values_set = sorted(list(set(inner_idx_values)))
#      19             if inner_idx_values != inner_idx_values_set:
# ---> 20                 raise IndexError(
#      21                     f"The Thicket.dataframe's index has duplicate values. {inner_idx_values}"
#      22                 )
#
# IndexError: The Thicket.dataframe's index has duplicate values. [64, 64, 64, 64, 64, 64, 64, 128, 128, 128, 128, 128, 128, 128, 256, 256, 256, 256, 256, 256, 256, 512, 512, 512, 512, 512, 512, 512, 1024, 1024, 1024, 1024, 1024, 1024, 1024]

# %%
ctk.dataframe

# %%
# Drop unwanted columns
ctk.dataframe = ctk.dataframe.reset_index().drop(("node"), axis=1)
# Rename index to remove tuple
ctk.dataframe = ctk.dataframe.rename({("name", ""): "name", ("num_threads", ""): "num_threads"}).set_index(["name", "num_threads"])
# Drop "time" label as it is redundant
#ctk.dataframe.columns = ctk.dataframe.columns.droplevel(1)

# %%
# Define common variables
function_names = set(ctk.dataframe.index.get_level_values("name"))
num_threads = sorted(list(set(ctk.dataframe.index.get_level_values("num_threads"))))
input_sizes = sorted(list(set(ctk.dataframe.columns.get_level_values(0))))

# %%
def plot_mpl(df, title, xlabel, ylabel):
    fig = plt.figure()
    ax = fig.add_subplot(1, 1, 1)
    ax.plot(
        df,
        marker='o',
    )
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.legend(df.columns)
    plt.grid(True)
    #plt.yscale("log", base=10)
   # plt.xscale("log", base=2)
    plt.xticks(num_threads)
    plt.show()
    return fig, ax

# %%
for name in function_names:
     for size in input_sizes:
        plot_mpl(
            df=ctk.dataframe.loc[name],
            title=f"RADIX CUDA, {name}, 1% Perturbed", 
            xlabel="num_threads",
            ylabel="Time (seconds)",
        )

# %%
#speedup=ctk.dataframe.loc["main",64]/ctk.dataframe.loc["main"]
speedup=ctk.dataframe.loc["comp_large",64]/ctk.dataframe.loc["comp_large"]
#speedup=ctk.dataframe.loc["comm",64]/ctk.dataframe.loc["comm"]
speedup

# %%
plot_mpl(
    df=speedup,
    title=f"RADIX CUDA, comp_large, 1% Perturbed", 
    xlabel="num_threads",
    ylabel="Speed Up",
)

# %%
ctk.dataframe.loc["comp_large"]
