# %%
import sys
sys.path.append("/scratch/group/csce435-f23/python-3.8.17/lib/python3.8/site-packages")
sys.path.append("/scratch/group/csce435-f23/thicket")
from glob import glob

import matplotlib.pyplot as plt
import pandas as pd
import thicket as th

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

# %%
#strong scaling
# tk = th.Thicket.from_caliperreader(glob("*-v65536-*.cali"))
# tk = th.Thicket.from_caliperreader(glob("*-v262144-*.cali"))
# tk = th.Thicket.from_caliperreader(glob("*-v1048576-*.cali"))
# tk = th.Thicket.from_caliperreader(glob("*-v4194304-*.cali"))
# tk = th.Thicket.from_caliperreader(glob("*-v16777216-*.cali"))
# tk = th.Thicket.from_caliperreader(glob("*-v67108864-*.cali"))
#tk = th.Thicket.from_caliperreader(glob("*-v268435456-*.cali"))

#speedup and weak
#tk = th.Thicket.from_caliperreader(glob("*-i1*.cali"))
#tk = th.Thicket.from_caliperreader(glob("*-i2*.cali"))
#tk = th.Thicket.from_caliperreader(glob("*-i3*.cali"))
tk = th.Thicket.from_caliperreader(glob("*-i4*.cali"))
tk.dataframe = tk.dataframe.drop(["nid", "spot.channel", "Total time", "Min time/rank", "Max time/rank", "Min GPU time/rank", "Max GPU time/rank", "Total GPU time", "Avg GPU time/rank"], axis=1)#,"Avg time/rank", "Min time/rank", "Max time/rank", "Total time", "Avg GPU time/rank", "Min GPU time/rank", "Max GPU time/rank", "Total GPU time"
tk.dataframe
# Out:
#                                                               Avg time/rank  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              414498271        1.361450
#                                                   627822010       34.108518
#                                                   675422748       17.537020
#                                                   1221154219    1318.166902
#                                                   1750563714       4.455470
#                                                   2307086009       9.219790
#                                                   2470599784      66.631597
#                                                   2566690557     161.863480
#                                                   3144157472      80.723746
#                                                   3186243202     321.628945
#                                                   3189081541     133.361027
#                                                   3362082510      18.187472
#                                                   3578694289     640.872669
#                                                   3613854097       8.974464
#                                                   3869713418       2.442157
# {'name': 'comm', 'type': 'function'}              414498271        0.008438
#                                                   627822010        0.122816
#                                                   675422748        0.060777
#                                                   1221154219       1.585897
#                                                   1750563714       0.034753
#                                                   2307086009       0.074383
#                                                   2470599784       0.254116
#                                                   2566690557       0.186887
#                                                   3144157472       0.094442
#                                                   3186243202       0.374713
#                                                   3189081541       0.806194
#                                                   3362082510       0.159063
#                                                   3578694289       0.756668
#                                                   3613854097       0.030279
#                                                   3869713418       0.017462
# {'name': 'comm_large', 'type': 'function'}        414498271        0.008167
#                                                   627822010        0.118744
#                                                   675422748        0.059227
#                                                   1221154219       1.494664
#                                                   1750563714       0.032930
#                                                   2307086009       0.066442
#                                                   2470599784       0.238698
#                                                   2566690557       0.183717
#                                                   3144157472       0.092223
#                                                   3186243202       0.365838
#                                                   3189081541       0.736752
#                                                   3362082510       0.133097
#                                                   3578694289       0.738315
#                                                   3613854097       0.029656
#                                                   3869713418       0.016684
# {'name': 'comm_small', 'type': 'function'}        414498271        0.000134
#                                                   627822010        0.003909
#                                                   675422748        0.001387
#                                                   1221154219       0.091029
#                                                   1750563714       0.001670
#                                                   2307086009       0.007780
#                                                   2470599784       0.015254
#                                                   2566690557       0.002968
#                                                   3144157472       0.002046
#                                                   3186243202       0.008694
#                                                   3189081541       0.069261
#                                                   3362082510       0.025797
#                                                   3578694289       0.018157
#                                                   3613854097       0.000454
#                                                   3869713418       0.000623
# {'name': 'comp', 'type': 'function'}              414498271        0.975122
#                                                   627822010       32.922533
#                                                   675422748       16.766685
#                                                   1221154219    1307.229427
#                                                   1750563714       3.913525
#                                                   2307086009       8.448721
#                                                   2470599784      64.602289
#                                                   2566690557     160.105348
#                                                   3144157472      79.618616
#                                                   3186243202     318.576493
#                                                   3189081541     129.173387
#                                                   3362082510      16.985849
#                                                   3578694289     635.188368
#                                                   3613854097       8.402203
#                                                   3869713418       1.988554
# {'name': 'comp_large', 'type': 'function'}        414498271        0.974667
#                                                   627822010       32.921757
#                                                   675422748       16.765218
#                                                   1221154219    1307.228636
#                                                   1750563714       3.913255
#                                                   2307086009       8.448491
#                                                   2470599784      64.601805
#                                                   2566690557     160.098651
#                                                   3144157472      79.604008
#                                                   3186243202     318.573372
#                                                   3189081541     129.173083
#                                                   3362082510      16.985635
#                                                   3578694289     635.186867
#                                                   3613854097       8.400076
#                                                   3869713418       1.988203
# {'name': 'comp_small', 'type': 'function'}        414498271        0.000388
#                                                   627822010        0.000646
#                                                   675422748        0.001348
#                                                   1221154219       0.000644
#                                                   1750563714       0.000177
#                                                   2307086009       0.000108
#                                                   2470599784       0.000349
#                                                   2566690557       0.006542
#                                                   3144157472       0.014483
#                                                   3186243202       0.002977
#                                                   3189081541       0.000181
#                                                   3362082510       0.000074
#                                                   3578694289       0.001358
#                                                   3613854097       0.002025
#                                                   3869713418       0.000272
# {'name': 'correctness_check', 'type': 'function'} 414498271        0.000189
#                                                   627822010        0.000718
#                                                   675422748        0.000717
#                                                   1221154219       0.002759
#                                                   1750563714       0.000196
#                                                   2307086009       0.000195
#                                                   2470599784       0.000722
#                                                   2566690557       0.002771
#                                                   3144157472       0.002772
#                                                   3186243202       0.002758
#                                                   3189081541       0.000712
#                                                   3362082510       0.000196
#                                                   3578694289       0.002763
#                                                   3613854097       0.000712
#                                                   3869713418       0.000193
# {'name': 'data_init', 'type': 'function'}         414498271        0.000251
#                                                   627822010        0.000963
#                                                   675422748        0.000974
#                                                   1221154219       0.003956
#                                                   1750563714       0.000254
#                                                   2307086009       0.000254
#                                                   2470599784       0.000980
#                                                   2566690557       0.003600
#                                                   3144157472       0.003584
#                                                   3186243202       0.003826
#                                                   3189081541       0.000999
#                                                   3362082510       0.000297
#                                                   3578694289       0.003945
#                                                   3613854097       0.000988
#                                                   3869713418       0.000287
#
#                                                                            name
# node                                              profile
# {'name': 'main', 'type': 'function'}              414498271                main
#                                                   627822010                main
#                                                   675422748                main
#                                                   1221154219               main
#                                                   1750563714               main
#                                                   2307086009               main
#                                                   2470599784               main
#                                                   2566690557               main
#                                                   3144157472               main
#                                                   3186243202               main
#                                                   3189081541               main
#                                                   3362082510               main
#                                                   3578694289               main
#                                                   3613854097               main
#                                                   3869713418               main
# {'name': 'comm', 'type': 'function'}              414498271                comm
#                                                   627822010                comm
#                                                   675422748                comm
#                                                   1221154219               comm
#                                                   1750563714               comm
#                                                   2307086009               comm
#                                                   2470599784               comm
#                                                   2566690557               comm
#                                                   3144157472               comm
#                                                   3186243202               comm
#                                                   3189081541               comm
#                                                   3362082510               comm
#                                                   3578694289               comm
#                                                   3613854097               comm
#                                                   3869713418               comm
# {'name': 'comm_large', 'type': 'function'}        414498271          comm_large
#                                                   627822010          comm_large
#                                                   675422748          comm_large
#                                                   1221154219         comm_large
#                                                   1750563714         comm_large
#                                                   2307086009         comm_large
#                                                   2470599784         comm_large
#                                                   2566690557         comm_large
#                                                   3144157472         comm_large
#                                                   3186243202         comm_large
#                                                   3189081541         comm_large
#                                                   3362082510         comm_large
#                                                   3578694289         comm_large
#                                                   3613854097         comm_large
#                                                   3869713418         comm_large
# {'name': 'comm_small', 'type': 'function'}        414498271          comm_small
#                                                   627822010          comm_small
#                                                   675422748          comm_small
#                                                   1221154219         comm_small
#                                                   1750563714         comm_small
#                                                   2307086009         comm_small
#                                                   2470599784         comm_small
#                                                   2566690557         comm_small
#                                                   3144157472         comm_small
#                                                   3186243202         comm_small
#                                                   3189081541         comm_small
#                                                   3362082510         comm_small
#                                                   3578694289         comm_small
#                                                   3613854097         comm_small
#                                                   3869713418         comm_small
# {'name': 'comp', 'type': 'function'}              414498271                comp
#                                                   627822010                comp
#                                                   675422748                comp
#                                                   1221154219               comp
#                                                   1750563714               comp
#                                                   2307086009               comp
#                                                   2470599784               comp
#                                                   2566690557               comp
#                                                   3144157472               comp
#                                                   3186243202               comp
#                                                   3189081541               comp
#                                                   3362082510               comp
#                                                   3578694289               comp
#                                                   3613854097               comp
#                                                   3869713418               comp
# {'name': 'comp_large', 'type': 'function'}        414498271          comp_large
#                                                   627822010          comp_large
#                                                   675422748          comp_large
#                                                   1221154219         comp_large
#                                                   1750563714         comp_large
#                                                   2307086009         comp_large
#                                                   2470599784         comp_large
#                                                   2566690557         comp_large
#                                                   3144157472         comp_large
#                                                   3186243202         comp_large
#                                                   3189081541         comp_large
#                                                   3362082510         comp_large
#                                                   3578694289         comp_large
#                                                   3613854097         comp_large
#                                                   3869713418         comp_large
# {'name': 'comp_small', 'type': 'function'}        414498271          comp_small
#                                                   627822010          comp_small
#                                                   675422748          comp_small
#                                                   1221154219         comp_small
#                                                   1750563714         comp_small
#                                                   2307086009         comp_small
#                                                   2470599784         comp_small
#                                                   2566690557         comp_small
#                                                   3144157472         comp_small
#                                                   3186243202         comp_small
#                                                   3189081541         comp_small
#                                                   3362082510         comp_small
#                                                   3578694289         comp_small
#                                                   3613854097         comp_small
#                                                   3869713418         comp_small
# {'name': 'correctness_check', 'type': 'function'} 414498271   correctness_check
#                                                   627822010   correctness_check
#                                                   675422748   correctness_check
#                                                   1221154219  correctness_check
#                                                   1750563714  correctness_check
#                                                   2307086009  correctness_check
#                                                   2470599784  correctness_check
#                                                   2566690557  correctness_check
#                                                   3144157472  correctness_check
#                                                   3186243202  correctness_check
#                                                   3189081541  correctness_check
#                                                   3362082510  correctness_check
#                                                   3578694289  correctness_check
#                                                   3613854097  correctness_check
#                                                   3869713418  correctness_check
# {'name': 'data_init', 'type': 'function'}         414498271           data_init
#                                                   627822010           data_init
#                                                   675422748           data_init
#                                                   1221154219          data_init
#                                                   1750563714          data_init
#                                                   2307086009          data_init
#                                                   2470599784          data_init
#                                                   2566690557          data_init
#                                                   3144157472          data_init
#                                                   3186243202          data_init
#                                                   3189081541          data_init
#                                                   3362082510          data_init
#                                                   3578694289          data_init
#                                                   3613854097          data_init
#                                                   3869713418          data_init

# %%
tk.metadata
# Out:
#            cali.caliper.version  \
# profile
# 414498271            2.11.0-dev
# 627822010            2.11.0-dev
# 675422748            2.11.0-dev
# 1221154219           2.11.0-dev
# 1750563714           2.11.0-dev
# 2307086009           2.11.0-dev
# 2470599784           2.11.0-dev
# 2566690557           2.11.0-dev
# 3144157472           2.11.0-dev
# 3186243202           2.11.0-dev
# 3189081541           2.11.0-dev
# 3362082510           2.11.0-dev
# 3578694289           2.11.0-dev
# 3613854097           2.11.0-dev
# 3869713418           2.11.0-dev
#
#                                                  spot.metrics  \
# profile
# 414498271   min#inclusive#sum#time.duration,max#inclusive#...
# 627822010   min#inclusive#sum#time.duration,max#inclusive#...
# 675422748   min#inclusive#sum#time.duration,max#inclusive#...
# 1221154219  min#inclusive#sum#time.duration,max#inclusive#...
# 1750563714  min#inclusive#sum#time.duration,max#inclusive#...
# 2307086009  min#inclusive#sum#time.duration,max#inclusive#...
# 2470599784  min#inclusive#sum#time.duration,max#inclusive#...
# 2566690557  min#inclusive#sum#time.duration,max#inclusive#...
# 3144157472  min#inclusive#sum#time.duration,max#inclusive#...
# 3186243202  min#inclusive#sum#time.duration,max#inclusive#...
# 3189081541  min#inclusive#sum#time.duration,max#inclusive#...
# 3362082510  min#inclusive#sum#time.duration,max#inclusive#...
# 3578694289  min#inclusive#sum#time.duration,max#inclusive#...
# 3613854097  min#inclusive#sum#time.duration,max#inclusive#...
# 3869713418  min#inclusive#sum#time.duration,max#inclusive#...
#
#            spot.timeseries.metrics  spot.format.version  \
# profile
# 414498271                                             2
# 627822010                                             2
# 675422748                                             2
# 1221154219                                            2
# 1750563714                                            2
# 2307086009                                            2
# 2470599784                                            2
# 2566690557                                            2
# 3144157472                                            2
# 3186243202                                            2
# 3189081541                                            2
# 3362082510                                            2
# 3578694289                                            2
# 3613854097                                            2
# 3869713418                                            2
#
#                        spot.options  spot.channels cali.channel  \
# profile
# 414498271   cuda.gputime,node.order  regionprofile         spot
# 627822010   cuda.gputime,node.order  regionprofile         spot
# 675422748   cuda.gputime,node.order  regionprofile         spot
# 1221154219  cuda.gputime,node.order  regionprofile         spot
# 1750563714  cuda.gputime,node.order  regionprofile         spot
# 2307086009  cuda.gputime,node.order  regionprofile         spot
# 2470599784  cuda.gputime,node.order  regionprofile         spot
# 2566690557  cuda.gputime,node.order  regionprofile         spot
# 3144157472  cuda.gputime,node.order  regionprofile         spot
# 3186243202  cuda.gputime,node.order  regionprofile         spot
# 3189081541  cuda.gputime,node.order  regionprofile         spot
# 3362082510  cuda.gputime,node.order  regionprofile         spot
# 3578694289  cuda.gputime,node.order  regionprofile         spot
# 3613854097  cuda.gputime,node.order  regionprofile         spot
# 3869713418  cuda.gputime,node.order  regionprofile         spot
#
#            spot:cuda.gputime spot:node.order             spot:output  \
# profile
# 414498271               true            true      t64-v65536-i4.cali
# 627822010               true            true    t256-v262144-i4.cali
# 675422748               true            true    t128-v262144-i4.cali
# 1221154219              true            true  t1024-v1048576-i4.cali
# 1750563714              true            true     t256-v65536-i4.cali
# 2307086009              true            true     t512-v65536-i4.cali
# 2470599784              true            true    t512-v262144-i4.cali
# 2566690557              true            true   t128-v1048576-i4.cali
# 3144157472              true            true    t64-v1048576-i4.cali
# 3186243202              true            true   t256-v1048576-i4.cali
# 3189081541              true            true   t1024-v262144-i4.cali
# 3362082510              true            true    t1024-v65536-i4.cali
# 3578694289              true            true   t512-v1048576-i4.cali
# 3613854097              true            true     t64-v262144-i4.cali
# 3869713418              true            true     t128-v65536-i4.cali
#
#             launchdate                                          libraries  \
# profile
# 414498271   1701363542  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 627822010   1701363420  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 675422748   1701363380  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1221154219  1701362722  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1750563714  1701363563  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2307086009  1701363562  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2470599784  1701363420  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2566690557  1701363210  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3144157472  1701363210  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3186243202  1701362800  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3189081541  1701363462  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3362082510  1701363583  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3578694289  1701362800  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3613854097  1701363380  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3869713418  1701363542  [/scratch/group/csce435-f23/Caliper/caliper/li...
#
#                                  cmdline cluster    Algorithm  \
# profile
# 414498271       [./sample, 64, 65536, 4]       g  Sample Sort
# 627822010     [./sample, 256, 262144, 4]       g  Sample Sort
# 675422748     [./sample, 128, 262144, 4]       g  Sample Sort
# 1221154219  [./sample, 1024, 1048576, 4]       g  Sample Sort
# 1750563714     [./sample, 256, 65536, 4]       g  Sample Sort
# 2307086009     [./sample, 512, 65536, 4]       g  Sample Sort
# 2470599784    [./sample, 512, 262144, 4]       g  Sample Sort
# 2566690557   [./sample, 128, 1048576, 4]       g  Sample Sort
# 3144157472    [./sample, 64, 1048576, 4]       g  Sample Sort
# 3186243202   [./sample, 256, 1048576, 4]       g  Sample Sort
# 3189081541   [./sample, 1024, 262144, 4]       g  Sample Sort
# 3362082510    [./sample, 1024, 65536, 4]       g  Sample Sort
# 3578694289   [./sample, 512, 1048576, 4]       g  Sample Sort
# 3613854097     [./sample, 64, 262144, 4]       g  Sample Sort
# 3869713418     [./sample, 128, 65536, 4]       g  Sample Sort
#
#            ProgrammingModel Datatype  SizeOfDatatype  InputSize     InputType  \
# profile
# 414498271              CUDA      int               4      65536  1% Perturbed
# 627822010              CUDA      int               4     262144  1% Perturbed
# 675422748              CUDA      int               4     262144  1% Perturbed
# 1221154219             CUDA      int               4    1048576  1% Perturbed
# 1750563714             CUDA      int               4      65536  1% Perturbed
# 2307086009             CUDA      int               4      65536  1% Perturbed
# 2470599784             CUDA      int               4     262144  1% Perturbed
# 2566690557             CUDA      int               4    1048576  1% Perturbed
# 3144157472             CUDA      int               4    1048576  1% Perturbed
# 3186243202             CUDA      int               4    1048576  1% Perturbed
# 3189081541             CUDA      int               4     262144  1% Perturbed
# 3362082510             CUDA      int               4      65536  1% Perturbed
# 3578694289             CUDA      int               4    1048576  1% Perturbed
# 3613854097             CUDA      int               4     262144  1% Perturbed
# 3869713418             CUDA      int               4      65536  1% Perturbed
#
#             num_threads  num_blocks  group_num implementation_source  main  \
# profile
# 414498271            64        1024         10           Handwritten  main
# 627822010           256        1024         10           Handwritten  main
# 675422748           128        2048         10           Handwritten  main
# 1221154219         1024        1024         10           Handwritten  main
# 1750563714          256         256         10           Handwritten  main
# 2307086009          512         128         10           Handwritten  main
# 2470599784          512         512         10           Handwritten  main
# 2566690557          128        8192         10           Handwritten  main
# 3144157472           64       16384         10           Handwritten  main
# 3186243202          256        4096         10           Handwritten  main
# 3189081541         1024         256         10           Handwritten  main
# 3362082510         1024          64         10           Handwritten  main
# 3578694289          512        2048         10           Handwritten  main
# 3613854097           64        4096         10           Handwritten  main
# 3869713418          128         512         10           Handwritten  main
#
#             data_init  comm  comp  comm_large  comm_small  comp_large  \
# profile
# 414498271   data_init  comm  comp  comm_large  comm_small  comp_large
# 627822010   data_init  comm  comp  comm_large  comm_small  comp_large
# 675422748   data_init  comm  comp  comm_large  comm_small  comp_large
# 1221154219  data_init  comm  comp  comm_large  comm_small  comp_large
# 1750563714  data_init  comm  comp  comm_large  comm_small  comp_large
# 2307086009  data_init  comm  comp  comm_large  comm_small  comp_large
# 2470599784  data_init  comm  comp  comm_large  comm_small  comp_large
# 2566690557  data_init  comm  comp  comm_large  comm_small  comp_large
# 3144157472  data_init  comm  comp  comm_large  comm_small  comp_large
# 3186243202  data_init  comm  comp  comm_large  comm_small  comp_large
# 3189081541  data_init  comm  comp  comm_large  comm_small  comp_large
# 3362082510  data_init  comm  comp  comm_large  comm_small  comp_large
# 3578694289  data_init  comm  comp  comm_large  comm_small  comp_large
# 3613854097  data_init  comm  comp  comm_large  comm_small  comp_large
# 3869713418  data_init  comm  comp  comm_large  comm_small  comp_large
#
#             comp_small  correctness_check
# profile
# 414498271   comp_small  correctness_check
# 627822010   comp_small  correctness_check
# 675422748   comp_small  correctness_check
# 1221154219  comp_small  correctness_check
# 1750563714  comp_small  correctness_check
# 2307086009  comp_small  correctness_check
# 2470599784  comp_small  correctness_check
# 2566690557  comp_small  correctness_check
# 3144157472  comp_small  correctness_check
# 3186243202  comp_small  correctness_check
# 3189081541  comp_small  correctness_check
# 3362082510  comp_small  correctness_check
# 3578694289  comp_small  correctness_check
# 3613854097  comp_small  correctness_check
# 3869713418  comp_small  correctness_check

# %%
tk.metadata.columns
# Out:
# Index(['cali.caliper.version', 'spot.metrics', 'spot.timeseries.metrics',
#        'spot.format.version', 'spot.options', 'spot.channels', 'cali.channel',
#        'spot:cuda.gputime', 'spot:node.order', 'spot:output', 'launchdate',
#        'libraries', 'cmdline', 'cluster', 'Algorithm', 'ProgrammingModel',
#        'Datatype', 'SizeOfDatatype', 'InputSize', 'InputType', 'num_threads',
#        'num_blocks', 'group_num', 'implementation_source', 'main', 'data_init',
#        'comm', 'comp', 'comm_large', 'comm_small', 'comp_large', 'comp_small',
#        'correctness_check'],
#       dtype='object')

# %%
#gb = tk.groupby("InputType")
gb = tk.groupby("InputSize")
# Out:
# 3  thickets created...
# {65536: <thicket.thicket.Thicket object at 0x2b0f7acafb50>, 262144: <thicket.thicket.Thicket object at 0x2b0f7ace83a0>, 1048576: <thicket.thicket.Thicket object at 0x2b0f7ac73ca0>}

# %%
ctk = th.Thicket.concat_thickets(
    thickets=list(gb.values()),
    headers=list(gb.keys()),
    axis="columns",
     metadata_key="num_threads"
)

# %%
ctk.dataframe
# Out:
#                                                                       65536  \
#                                                               Avg time/rank
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              64               1.361450
#                                                   128              2.442157
#                                                   256              4.455470
#                                                   512              9.219790
#                                                   1024            18.187472
# {'name': 'comm', 'type': 'function'}              64               0.008438
#                                                   128              0.017462
#                                                   256              0.034753
#                                                   512              0.074383
#                                                   1024             0.159063
# {'name': 'comm_large', 'type': 'function'}        64               0.008167
#                                                   128              0.016684
#                                                   256              0.032930
#                                                   512              0.066442
#                                                   1024             0.133097
# {'name': 'comm_small', 'type': 'function'}        64               0.000134
#                                                   128              0.000623
#                                                   256              0.001670
#                                                   512              0.007780
#                                                   1024             0.025797
# {'name': 'comp', 'type': 'function'}              64               0.975122
#                                                   128              1.988554
#                                                   256              3.913525
#                                                   512              8.448721
#                                                   1024            16.985849
# {'name': 'comp_large', 'type': 'function'}        64               0.974667
#                                                   128              1.988203
#                                                   256              3.913255
#                                                   512              8.448491
#                                                   1024            16.985635
# {'name': 'comp_small', 'type': 'function'}        64               0.000388
#                                                   128              0.000272
#                                                   256              0.000177
#                                                   512              0.000108
#                                                   1024             0.000074
# {'name': 'correctness_check', 'type': 'function'} 64               0.000189
#                                                   128              0.000193
#                                                   256              0.000196
#                                                   512              0.000195
#                                                   1024             0.000196
# {'name': 'data_init', 'type': 'function'}         64               0.000251
#                                                   128              0.000287
#                                                   256              0.000254
#                                                   512              0.000254
#                                                   1024             0.000297
#
#                                                                      262144  \
#                                                               Avg time/rank
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              64               8.974464
#                                                   128             17.537020
#                                                   256             34.108518
#                                                   512             66.631597
#                                                   1024           133.361027
# {'name': 'comm', 'type': 'function'}              64               0.030279
#                                                   128              0.060777
#                                                   256              0.122816
#                                                   512              0.254116
#                                                   1024             0.806194
# {'name': 'comm_large', 'type': 'function'}        64               0.029656
#                                                   128              0.059227
#                                                   256              0.118744
#                                                   512              0.238698
#                                                   1024             0.736752
# {'name': 'comm_small', 'type': 'function'}        64               0.000454
#                                                   128              0.001387
#                                                   256              0.003909
#                                                   512              0.015254
#                                                   1024             0.069261
# {'name': 'comp', 'type': 'function'}              64               8.402203
#                                                   128             16.766685
#                                                   256             32.922533
#                                                   512             64.602289
#                                                   1024           129.173387
# {'name': 'comp_large', 'type': 'function'}        64               8.400076
#                                                   128             16.765218
#                                                   256             32.921757
#                                                   512             64.601805
#                                                   1024           129.173083
# {'name': 'comp_small', 'type': 'function'}        64               0.002025
#                                                   128              0.001348
#                                                   256              0.000646
#                                                   512              0.000349
#                                                   1024             0.000181
# {'name': 'correctness_check', 'type': 'function'} 64               0.000712
#                                                   128              0.000717
#                                                   256              0.000718
#                                                   512              0.000722
#                                                   1024             0.000712
# {'name': 'data_init', 'type': 'function'}         64               0.000988
#                                                   128              0.000974
#                                                   256              0.000963
#                                                   512              0.000980
#                                                   1024             0.000999
#
#                                                                     1048576  \
#                                                               Avg time/rank
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              64              80.723746
#                                                   128            161.863480
#                                                   256            321.628945
#                                                   512            640.872669
#                                                   1024          1318.166902
# {'name': 'comm', 'type': 'function'}              64               0.094442
#                                                   128              0.186887
#                                                   256              0.374713
#                                                   512              0.756668
#                                                   1024             1.585897
# {'name': 'comm_large', 'type': 'function'}        64               0.092223
#                                                   128              0.183717
#                                                   256              0.365838
#                                                   512              0.738315
#                                                   1024             1.494664
# {'name': 'comm_small', 'type': 'function'}        64               0.002046
#                                                   128              0.002968
#                                                   256              0.008694
#                                                   512              0.018157
#                                                   1024             0.091029
# {'name': 'comp', 'type': 'function'}              64              79.618616
#                                                   128            160.105348
#                                                   256            318.576493
#                                                   512            635.188368
#                                                   1024          1307.229427
# {'name': 'comp_large', 'type': 'function'}        64              79.604008
#                                                   128            160.098651
#                                                   256            318.573372
#                                                   512            635.186867
#                                                   1024          1307.228636
# {'name': 'comp_small', 'type': 'function'}        64               0.014483
#                                                   128              0.006542
#                                                   256              0.002977
#                                                   512              0.001358
#                                                   1024             0.000644
# {'name': 'correctness_check', 'type': 'function'} 64               0.002772
#                                                   128              0.002771
#                                                   256              0.002758
#                                                   512              0.002763
#                                                   1024             0.002759
# {'name': 'data_init', 'type': 'function'}         64               0.003584
#                                                   128              0.003600
#                                                   256              0.003826
#                                                   512              0.003945
#                                                   1024             0.003956
#
#                                                                             name
#
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              64                        main
#                                                   128                       main
#                                                   256                       main
#                                                   512                       main
#                                                   1024                      main
# {'name': 'comm', 'type': 'function'}              64                        comm
#                                                   128                       comm
#                                                   256                       comm
#                                                   512                       comm
#                                                   1024                      comm
# {'name': 'comm_large', 'type': 'function'}        64                  comm_large
#                                                   128                 comm_large
#                                                   256                 comm_large
#                                                   512                 comm_large
#                                                   1024                comm_large
# {'name': 'comm_small', 'type': 'function'}        64                  comm_small
#                                                   128                 comm_small
#                                                   256                 comm_small
#                                                   512                 comm_small
#                                                   1024                comm_small
# {'name': 'comp', 'type': 'function'}              64                        comp
#                                                   128                       comp
#                                                   256                       comp
#                                                   512                       comp
#                                                   1024                      comp
# {'name': 'comp_large', 'type': 'function'}        64                  comp_large
#                                                   128                 comp_large
#                                                   256                 comp_large
#                                                   512                 comp_large
#                                                   1024                comp_large
# {'name': 'comp_small', 'type': 'function'}        64                  comp_small
#                                                   128                 comp_small
#                                                   256                 comp_small
#                                                   512                 comp_small
#                                                   1024                comp_small
# {'name': 'correctness_check', 'type': 'function'} 64           correctness_check
#                                                   128          correctness_check
#                                                   256          correctness_check
#                                                   512          correctness_check
#                                                   1024         correctness_check
# {'name': 'data_init', 'type': 'function'}         64                   data_init
#                                                   128                  data_init
#                                                   256                  data_init
#                                                   512                  data_init
#                                                   1024                 data_init

# %%
# Drop unwanted columns
ctk.dataframe = ctk.dataframe.reset_index().drop(("node"), axis=1)
# Rename index to remove tuple
ctk.dataframe = ctk.dataframe.rename({("name", ""): "name", ("num_threads", ""): "num_threads"}).set_index(["name", "num_threads"])
# Drop "time" label as it is redundant
#ctk.dataframe.columns = ctk.dataframe.columns.droplevel(1)
# Out:
# /sw/hprc/sw/Python/virtualenvs/Python/3.8.2/default_jupyter_notebook/lib/python3.8/site-packages/pandas/core/generic.py:4150: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)

# %%
# Define common variables
function_names = set(ctk.dataframe.index.get_level_values("name"))
num_threads = sorted(list(set(ctk.dataframe.index.get_level_values("num_threads"))))
input_sizes = sorted(list(set(ctk.dataframe.columns.get_level_values(0))))

# %%
def plot_mpl(df, title, xlabel, ylabel):
    fig = plt.figure()
    ax = fig.add_subplot(1, 1, 1)
    ax.plot(
        df,
        marker='o',
    )
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.legend(df.columns)
    plt.grid(True)
    #plt.yscale("log", base=10)
   # plt.xscale("log", base=2)
    plt.xticks(num_threads)
    plt.show()
    return fig, ax

# %%
for name in function_names:
    plot_mpl(
        df=ctk.dataframe.loc[name],
        title=f"Weak Scaling: 1% Perturbed, {name}", 
        xlabel="num_threads",
        ylabel="Time (seconds)",
    )

# %%
#speedup=ctk.dataframe.loc["main",64]/ctk.dataframe.loc["main"]
#speedup=ctk.dataframe.loc["comp_large",64]/ctk.dataframe.loc["comp_large"]
speedup=ctk.dataframe.loc["comm",64]/ctk.dataframe.loc["comm"]
speedup
# Out:
#                     65536        262144       1048576
#             Avg time/rank Avg time/rank Avg time/rank
# num_threads
# 64               1.000000      1.000000      1.000000
# 128              0.483221      0.498198      0.505343
# 256              0.242799      0.246540      0.252038
# 512              0.113440      0.119154      0.124813
# 1024             0.053048      0.037558      0.059551

# %%
plot_mpl(
    df=speedup,
    title=f"Speed Up: 1% Perturbed, comm", 
    xlabel="num_threads",
    ylabel="Speed Up",
)
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:title={'center':'Speed Up: 1% Perturbed, comm'}, xlabel='num_threads', ylabel='Speed Up'>)
