# %%
import sys
sys.path.append("/scratch/group/csce435-f23/python-3.8.17/lib/python3.8/site-packages")
sys.path.append("/scratch/group/csce435-f23/thicket")
from glob import glob

import matplotlib.pyplot as plt
import pandas as pd

import thicket as th

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

# %%
import os

current_directory = os.getcwd()
print("Current directory:", current_directory)
# Out:
# Current directory: /scratch/user/shilpilasya/FinalProject/csce435/435Project/Builds/MPI

# %%
from thicket import Thicket
tk = th.Thicket.from_caliperreader(glob("*.cali"))
tk.dataframe = tk.dataframe.drop(["nid","spot.channel","Total time","Min time/rank","Max time/rank"], axis = 1)

# %%
tk.statsframe.dataframe["time"] = 1
tk.tree()
print(tk.tree())
# Out:
#   _____ _     _      _        _
#  |_   _| |__ (_) ___| | _____| |_
#    | | | '_ \| |/ __| |/ / _ \ __|
#    | | | | | | | (__|   <  __/ |_
#    |_| |_| |_|_|\___|_|\_\___|\__|  v2023.3.0
#
# 1.000 main
# ├─ 1.000 comm
# │  └─ 1.000 comm_large
# ├─ 1.000 comp
# │  └─ 1.000 comp_large
# │     └─ 1.000 comm
# │        └─ 1.000 comm_large
# ├─ 1.000 correctness_check
# └─ 1.000 data_init
#
# Legend (Metric: time Min: 1.00 Max: 1.00)
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
#
# name User code    ◀  Only in left graph    ▶  Only in right graph

# %%
tk.dataframe
# Out:
#                                                               Avg time/rank  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              474621069        3.434493
#                                                   565882098        0.854681
#                                                   708127808        6.371559
#                                                   1289940276       3.513608
#                                                   2356947410       3.918072
#                                                   3038603315       3.218298
#                                                   3931021394       8.935149
# {'name': 'comm', 'type': 'function'}              474621069        0.002700
#                                                   565882098        0.000117
#                                                   708127808        0.004021
#                                                   1289940276       0.005104
#                                                   2356947410       0.005765
#                                                   3038603315       0.000120
#                                                   3931021394       0.000164
# {'name': 'comm_large', 'type': 'function'}        474621069        0.002669
#                                                   565882098        0.000086
#                                                   708127808        0.003976
#                                                   1289940276       0.005086
#                                                   2356947410       0.005748
#                                                   3038603315       0.000101
#                                                   3931021394       0.000149
# {'name': 'comp', 'type': 'function'}              474621069        0.667633
#                                                   565882098        0.051253
#                                                   708127808        1.711345
#                                                   1289940276       0.695807
#                                                   2356947410       0.343491
#                                                   3038603315       0.669531
#                                                   3931021394       0.167988
# {'name': 'comp_large', 'type': 'function'}        474621069        0.667595
#                                                   565882098        0.051205
#                                                   708127808        1.703381
#                                                   1289940276       0.695734
#                                                   2356947410       0.343475
#                                                   3038603315       0.669498
#                                                   3931021394       0.167659
# {'name': 'comm', 'type': 'function'}              474621069        0.667295
#                                                   565882098        0.051162
#                                                   708127808        0.617570
#                                                   1289940276            NaN
#                                                   2356947410       0.343416
#                                                   3038603315       0.669428
#                                                   3931021394       0.167480
# {'name': 'comm_large', 'type': 'function'}        474621069        0.667053
#                                                   565882098        0.051105
#                                                   708127808        0.617153
#                                                   1289940276            NaN
#                                                   2356947410       0.343286
#                                                   3038603315       0.669263
#                                                   3931021394       0.167215
# {'name': 'correctness_check', 'type': 'function'} 474621069        0.000242
#                                                   565882098        0.000025
#                                                   708127808        0.003854
#                                                   1289940276            NaN
#                                                   2356947410       0.000018
#                                                   3038603315       0.000011
#                                                   3931021394       0.000005
# {'name': 'data_init', 'type': 'function'}         474621069        0.000049
#                                                   565882098        0.000053
#                                                   708127808        0.062190
#                                                   1289940276       0.000051
#                                                   2356947410       0.000033
#                                                   3038603315       0.000034
#                                                   3931021394       0.000034
#
#                                                               Variance time/rank  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              474621069             0.004365
#                                                   565882098             0.000120
#                                                   708127808             0.001665
#                                                   1289940276            0.001863
#                                                   2356947410            5.169225
#                                                   3038603315            0.002751
#                                                   3931021394            0.020143
# {'name': 'comm', 'type': 'function'}              474621069             0.000099
#                                                   565882098             0.000000
#                                                   708127808             0.000220
#                                                   1289940276            0.000230
#                                                   2356947410            0.000238
#                                                   3038603315            0.000000
#                                                   3931021394            0.000000
# {'name': 'comm_large', 'type': 'function'}        474621069             0.000099
#                                                   565882098             0.000000
#                                                   708127808             0.000219
#                                                   1289940276            0.000230
#                                                   2356947410            0.000238
#                                                   3038603315            0.000000
#                                                   3931021394            0.000000
# {'name': 'comp', 'type': 'function'}              474621069             0.004903
#                                                   565882098             0.000340
#                                                   708127808             0.004675
#                                                   1289940276            0.003530
#                                                   2356947410            0.000516
#                                                   3038603315            0.007349
#                                                   3931021394            0.008137
# {'name': 'comp_large', 'type': 'function'}        474621069             0.004903
#                                                   565882098             0.000340
#                                                   708127808             0.003336
#                                                   1289940276            0.003529
#                                                   2356947410            0.000516
#                                                   3038603315            0.007349
#                                                   3931021394            0.008162
# {'name': 'comm', 'type': 'function'}              474621069             0.004891
#                                                   565882098             0.000340
#                                                   708127808             0.010789
#                                                   1289940276                 NaN
#                                                   2356947410            0.000516
#                                                   3038603315            0.007349
#                                                   3931021394            0.008159
# {'name': 'comm_large', 'type': 'function'}        474621069             0.004894
#                                                   565882098             0.000339
#                                                   708127808             0.010788
#                                                   1289940276                 NaN
#                                                   2356947410            0.000516
#                                                   3038603315            0.007347
#                                                   3931021394            0.008158
# {'name': 'correctness_check', 'type': 'function'} 474621069             0.000001
#                                                   565882098             0.000000
#                                                   708127808             0.000222
#                                                   1289940276                 NaN
#                                                   2356947410            0.000000
#                                                   3038603315            0.000000
#                                                   3931021394            0.000000
# {'name': 'data_init', 'type': 'function'}         474621069             0.000000
#                                                   565882098             0.000000
#                                                   708127808             0.002122
#                                                   1289940276            0.000000
#                                                   2356947410            0.000000
#                                                   3038603315            0.000000
#                                                   3931021394            0.000000
#
#                                                                            name
# node                                              profile
# {'name': 'main', 'type': 'function'}              474621069                main
#                                                   565882098                main
#                                                   708127808                main
#                                                   1289940276               main
#                                                   2356947410               main
#                                                   3038603315               main
#                                                   3931021394               main
# {'name': 'comm', 'type': 'function'}              474621069                comm
#                                                   565882098                comm
#                                                   708127808                comm
#                                                   1289940276               comm
#                                                   2356947410               comm
#                                                   3038603315               comm
#                                                   3931021394               comm
# {'name': 'comm_large', 'type': 'function'}        474621069          comm_large
#                                                   565882098          comm_large
#                                                   708127808          comm_large
#                                                   1289940276         comm_large
#                                                   2356947410         comm_large
#                                                   3038603315         comm_large
#                                                   3931021394         comm_large
# {'name': 'comp', 'type': 'function'}              474621069                comp
#                                                   565882098                comp
#                                                   708127808                comp
#                                                   1289940276               comp
#                                                   2356947410               comp
#                                                   3038603315               comp
#                                                   3931021394               comp
# {'name': 'comp_large', 'type': 'function'}        474621069          comp_large
#                                                   565882098          comp_large
#                                                   708127808          comp_large
#                                                   1289940276         comp_large
#                                                   2356947410         comp_large
#                                                   3038603315         comp_large
#                                                   3931021394         comp_large
# {'name': 'comm', 'type': 'function'}              474621069                comm
#                                                   565882098                comm
#                                                   708127808                comm
#                                                   1289940276               None
#                                                   2356947410               comm
#                                                   3038603315               comm
#                                                   3931021394               comm
# {'name': 'comm_large', 'type': 'function'}        474621069          comm_large
#                                                   565882098          comm_large
#                                                   708127808          comm_large
#                                                   1289940276               None
#                                                   2356947410         comm_large
#                                                   3038603315         comm_large
#                                                   3931021394         comm_large
# {'name': 'correctness_check', 'type': 'function'} 474621069   correctness_check
#                                                   565882098   correctness_check
#                                                   708127808   correctness_check
#                                                   1289940276               None
#                                                   2356947410  correctness_check
#                                                   3038603315  correctness_check
#                                                   3931021394  correctness_check
# {'name': 'data_init', 'type': 'function'}         474621069           data_init
#                                                   565882098           data_init
#                                                   708127808           data_init
#                                                   1289940276          data_init
#                                                   2356947410          data_init
#                                                   3038603315          data_init
#                                                   3931021394          data_init

# %%
tk.metadata
# Out:
#            cali.caliper.version  mpi.world.size  \
# profile
# 474621069            2.11.0-dev              16
# 565882098            2.11.0-dev               4
# 708127808            2.11.0-dev              16
# 1289940276           2.11.0-dev              16
# 2356947410           2.11.0-dev              16
# 3038603315           2.11.0-dev              16
# 3931021394           2.11.0-dev              64
#
#                                                  spot.metrics  \
# profile
# 474621069   min#inclusive#sum#time.duration,max#inclusive#...
# 565882098   min#inclusive#sum#time.duration,max#inclusive#...
# 708127808   min#inclusive#sum#time.duration,max#inclusive#...
# 1289940276  min#inclusive#sum#time.duration,max#inclusive#...
# 2356947410  min#inclusive#sum#time.duration,max#inclusive#...
# 3038603315  min#inclusive#sum#time.duration,max#inclusive#...
# 3931021394  min#inclusive#sum#time.duration,max#inclusive#...
#
#            spot.timeseries.metrics  spot.format.version  \
# profile
# 474621069                                             2
# 565882098                                             2
# 708127808                                             2
# 1289940276                                            2
# 2356947410                                            2
# 3038603315                                            2
# 3931021394                                            2
#
#                         spot.options  spot.channels cali.channel  \
# profile
# 474621069   time.variance,node.order  regionprofile         spot
# 565882098   time.variance,node.order  regionprofile         spot
# 708127808   time.variance,node.order  regionprofile         spot
# 1289940276  time.variance,node.order  regionprofile         spot
# 2356947410  time.variance,node.order  regionprofile         spot
# 3038603315  time.variance,node.order  regionprofile         spot
# 3931021394  time.variance,node.order  regionprofile         spot
#
#            spot:node.order      spot:output spot:time.variance
# profile
# 474621069             true  p16-a64-i3.cali               true
# 565882098             true      p4-a16.cali               true
# 708127808             true  p16-a65536.cali               true
# 1289940276            true     p16-a64.cali               true
# 2356947410            true   p16-a2-i1.cali               true
# 3038603315            true      p16-a4.cali               true
# 3931021394            true     p64-a16.cali               true
